# %% [markdown]
# ## 1-й эксперимент

# %% [markdown]
# Ток разряда - 1.45 мА

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("data/exp1.csv", delimiter=",", skiprows=1)

Ur = data[:, 0]
Ua_times_2 = data[:, 1]

plt.title("1-й эксперимент")
plt.plot(Ur, Ua_times_2, marker='o', linestyle='')
plt.xlabel(r"$U_r, V$")
plt.ylabel(r"$2U_a, mV$")

plt.show()

# %% [markdown]
# 6.38 – максимальная амплитуда сигнала (интенсивность)

# %% [markdown]
# $\lambda=633$ нм

# %% [markdown]
# ## 2-й эксперимент

# %% [markdown]
# (2-1)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("data/exp2-1.csv", delimiter=",", skiprows=1)

I = data[:, 0]
nu = data[:, 1]

# аппроксимация прямой
a, b = np.polyfit(I, nu, 1)

# значения для линии
I_fit = np.linspace(I.min(), I.max(), 200)
nu_fit = a * I_fit + b

plt.title("2-й эксперимент (2-1)")
plt.plot(-a * I + b, nu, marker='o', linestyle='')
plt.plot(-a * I_fit + b, nu_fit, '-', label=f"$\\nu = {a:.3f} I + {b:.3f}$")
plt.xlabel(r"$\nu_I$, кГц")
plt.ylabel(r"$\nu$, kHz")

plt.legend()
plt.show()

# %% [markdown]
# (2-2)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("data/exp2-2.csv", delimiter=",", skiprows=1)

I = data[:, 0]
nu = -data[:, 1]

# аппроксимация прямой
a, b = np.polyfit(I, nu, 1)

# значения для линии
I_fit = np.linspace(I.min(), I.max(), 200)
nu_fit = a * I_fit + b

plt.title("2-й эксперимент (2-2)")
plt.plot(a * I + b, nu, marker='o', linestyle='')
plt.plot(a *I_fit + b, nu_fit, '-', label=f"$\\nu = {a:.3f} I + {b:.3f}$")
plt.xlabel(r"$\nu_I$, кГц")
plt.ylabel(r"$\nu$, kHz")

plt.legend()
plt.show()

# %% [markdown]
# (2-3)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("data/exp2-3.csv", delimiter=",", skiprows=1)

I = data[:, 0]
nu = data[:, 1]

# аппроксимация прямой
a, b = np.polyfit(I, nu, 1)

# значения для линии
I_fit = np.linspace(I.min(), I.max(), 200)
nu_fit = a * I_fit + b

plt.title("2-й эксперимент (2-3)")
plt.plot(-a * I + b, nu, marker='o', linestyle='')
plt.plot(-a * I_fit + b, nu_fit, '-', label=f"$\\nu = {a:.3f} I + {b:.3f}$")
plt.xlabel(r"$\nu_I$, кГц")
plt.ylabel(r"$\nu$, kHz")

plt.legend()
plt.show()

# %% [markdown]
# ## Обработка длительной работы гироскопа
