# %% [markdown]
# Ток разряда - 1.45 мА

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("exp1.csv", delimiter=",", skiprows=1)

Ur = data[:, 0]
Ua_times_2 = data[:, 1]

plt.title("Experimental Data Plot")
plt.plot(Ur, Ua_times_2, marker='o', linestyle='')
plt.xlabel("U_r, V")
plt.ylabel("2U_a, mV")

plt.show()

# %% [markdown]
# 6.38 – максимальная амплитуда сигнала (интенсивность)

# %% [markdown]
# $\lambda=633$ нм
