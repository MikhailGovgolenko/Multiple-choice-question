# %% [markdown]
# Ток разряда - 1.45 мА

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("exp1.csv", delimiter=",", skiprows=1)

Ur = data[:, 0]
Ua_times_2 = data[:, 1]

plt.title("1-й эксперимент")
plt.plot(Ur, Ua_times_2, marker='o', linestyle='')
plt.xlabel("U_r, V")
plt.ylabel("2U_a, mV")

plt.show()

# %% [markdown]
# 6.38 – максимальная амплитуда сигнала (интенсивность)

# %% [markdown]
# $\lambda=633$ нм

# %% [markdown]
# ## 2-й эксперимент

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("exp2.csv", delimiter=",", skiprows=1)

I = data[:, 0]
nu = data[:, 1]

plt.title("2-й эксперимент")
plt.plot(I, nu, marker='o', linestyle='')
plt.xlabel("I, A")
plt.ylabel("nu, kHz")

plt.show()
